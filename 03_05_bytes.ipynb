# %% [markdown]
# ### Bytes

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
smileyBytes = bytes(':)', 'utf-8')
smileyBytes
# Out:
# b':)'

# %%
smileyBytes = bytes('😊', 'utf-8')
smileyBytes
# Out:
# b'\xf0\x9f\x98\x8a'

# %%
smileyBytes.decode('utf-8')
# Out:
# '😊'

# %%
smileyBites = bytearray('😊', 'utf-8')

# %%
smileyBites
# Out:
# bytearray(b'\xf0\x9f\x98\x8a')

# %%
smileyBites[3] = int('9a', 16)

# %%
smileyBytes.decode('utf-8')
# Out:
# '😊'

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
smileyBytes = bytes('🙄', 'utf-8')
smileyBytes
# Out:
# b'\xf0\x9f\x99\x84'

# %%
smileyBytes.decode('utf-8')
# Out:
# '🙄'

# %%
smileyBytes = bytearray('🙄', 'utf-8')

# %%
smileyBytes
# Out:
# bytearray(b'\xf0\x9f\x99\x84')

# %%
smileyBytes[3] = int('85', 16)

# %%
smileyBytes.decode('utf-8')
# Out:
# '🙅'
