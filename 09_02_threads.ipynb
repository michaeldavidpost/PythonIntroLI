# %%
import threading
import time

# %% [markdown]
# ## Threads

# %%
def longSquare(num):
    time.sleep(1)
    return num**2

[longSquare(n) for n in range(0, 5)]
# Out:
# [0, 1, 4, 9, 16]

# %%
t1 = threading.Thread(target=longSquare, args=(1,))
t2 = threading.Thread(target=longSquare, args=(2,))

t1.start()
t2.start()

t1.join()
t2.join()

# %%
def longSquare(num, results):
    time.sleep(1)
    results[num] = num**2

results = {}
t1 = threading.Thread(target=longSquare, args=(1,results))
t2 = threading.Thread(target=longSquare, args=(2,results))

t1.start()
t2.start()

t1.join()
t2.join()

print(results)
# Out:
# {1: 1, 2: 4}

# %%
def longSquare(num, results):
    time.sleep(1)
    results[num] = num**2

results = {}
threads = [threading.Thread(target=longSquare, args=(n, results)) for n in range(0, 10)]
[t.start() for t in threads]
[t.join() for t in threads]
print(results)
# Out:
# {3: 9, 0: 0, 1: 1, 6: 36, 4: 16, 5: 25, 2: 4, 9: 81, 8: 64, 7: 49}

# %%
def longSquare(num, results):
    time.sleep(1)
    results[num] = num**2

results = {}
threads = [threading.Thread(target=longSquare, args=(n, results)) for n in range(0, 100)]
[t.start() for t in threads]
[t.join() for t in threads]
print(results)
# Out:
# {0: 0, 1: 1, 3: 9, 2: 4, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 10: 100, 9: 81, 14: 196, 11: 121, 16: 256, 15: 225, 12: 144, 13: 169, 20: 400, 17: 289, 18: 324, 19: 361, 22: 484, 21: 441, 23: 529, 24: 576, 25: 625, 27: 729, 28: 784, 26: 676, 31: 961, 29: 841, 30: 900, 34: 1156, 35: 1225, 33: 1089, 32: 1024, 37: 1369, 36: 1296, 38: 1444, 39: 1521, 41: 1681, 40: 1600, 42: 1764, 43: 1849, 44: 1936, 45: 2025, 46: 2116, 47: 2209, 48: 2304, 49: 2401, 50: 2500, 52: 2704, 51: 2601, 53: 2809, 55: 3025, 54: 2916, 56: 3136, 57: 3249, 58: 3364, 59: 3481, 61: 3721, 60: 3600, 62: 3844, 64: 4096, 63: 3969, 65: 4225, 66: 4356, 68: 4624, 67: 4489, 69: 4761, 70: 4900, 72: 5184, 71: 5041, 73: 5329, 74: 5476, 75: 5625, 76: 5776, 79: 6241, 78: 6084, 77: 5929, 80: 6400, 82: 6724, 81: 6561, 85: 7225, 83: 6889, 86: 7396, 84: 7056, 88: 7744, 90: 8100, 89: 7921, 87: 7569, 92: 8464, 91: 8281, 93: 8649, 94: 8836, 96: 9216, 95: 9025, 98: 9604, 97: 9409, 99: 9801}

# %%
def longSquare(num):
    time.sleep(1)
    return num**2

[longSquare(n) for n in range(0, 5)]
# Out:
# [0, 1, 4, 9, 16]

# %%
t1 = threading.Thread(target=longSquare, args=(1,))
t2 = threading.Thread(target=longSquare, args=(2,))

t1.start()
t2.start()

t1.join()
t2.join()

# %%
def longSquare(num, results):
    time.sleep(1)
    results[num] = num**2

results = {}
t1 = threading.Thread(target=longSquare, args=(1,results))
t2 = threading.Thread(target=longSquare, args=(2,results))

t1.start()
t2.start()

t1.join()
t2.join()

print(results)
# Out:
# {2: 4, 1: 1}

# %%
def longSquare(num, results):
    time.sleep(1)
    results[num] = num**2

results = {}
threads = [threading.Thread(target=longSquare, args=(n, results)) for n in range(0, 100)]
[t.start() for t in threads]
[t.join() for t in threads]
print(results)
# Out:
# {2: 4, 1: 1, 0: 0, 8: 64, 9: 81, 16: 256, 17: 289, 19: 361, 30: 900, 25: 625, 28: 784, 29: 841, 3: 9, 13: 169, 15: 225, 21: 441, 22: 484, 4: 16, 14: 196, 6: 36, 20: 400, 39: 1521, 40: 1600, 5: 25, 42: 1764, 43: 1849, 44: 1936, 45: 2025, 47: 2209, 7: 49, 38: 1444, 37: 1369, 32: 1024, 41: 1681, 46: 2116, 10: 100, 11: 121, 12: 144, 18: 324, 33: 1089, 23: 529, 70: 4900, 75: 5625, 82: 6724, 85: 7225, 86: 7396, 91: 8281, 92: 8464, 94: 8836, 95: 9025, 96: 9216, 97: 9409, 98: 9604, 99: 9801, 63: 3969, 81: 6561, 26: 676, 35: 1225, 36: 1296, 49: 2401, 50: 2500, 51: 2601, 52: 2704, 53: 2809, 60: 3600, 66: 4356, 74: 5476, 77: 5929, 79: 6241, 83: 6889, 84: 7056, 87: 7569, 93: 8649, 24: 576, 27: 729, 64: 4096, 61: 3721, 65: 4225, 69: 4761, 73: 5329, 78: 6084, 90: 8100, 62: 3844, 31: 961, 34: 1156, 67: 4489, 68: 4624, 80: 6400, 88: 7744, 89: 7921, 48: 2304, 57: 3249, 71: 5041, 72: 5184, 76: 5776, 54: 2916, 56: 3136, 55: 3025, 58: 3364, 59: 3481}
